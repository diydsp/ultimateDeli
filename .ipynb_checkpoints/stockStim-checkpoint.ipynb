# %%
#!/usr/bin/env python3

"""
swing trade to target amount
"""

import pdb
import random

# sim params
seqLen = 260  # days


class StockHolding:
    def __init__( self, name, price, qty ):
        self.name = name
        self.price = price
        self.qty = qty

    #@classmethod
    def iterate( self ):
        price = price + random.random()

    #@classmethod
    def print(self):
        print(f'{self.name}, {self.price}, {self.qty}')
        
class Portfolio:
    def __init__( self ):
        self.stockList = []
    
    #@classmethod
    def append( self, holding ):
        self.stockList.append( holding )
        
    #@classmethod
    def print(self):
        for holding in self.stockList:
            holding.print()
        
class Day:
    def __init__( self ):
        self.portfolio = []

    #@classmethod
    #def append( portfolio ):

# %%
DayList = []
for dayNumb in range(1,seqLen+1):

    #pdb.set_trace()

    # create some stocks
    stock = StockHolding( "abc", 15, 7 )
    stock2 = StockHolding( "xyz", 6, 16 )
    
    # add them to a portfolio
    portfolio = Portfolio()
    portfolio.append( stock )
    portfolio.append( stock2 )
    portfolio.print()

    # make a day
    day = Day()

    # set the portfolio to the day
    day.portfolio = portfolio
    
    # add the day to the list of days
    DayList.append( day )
# Out:
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# abc, 15, 7
# xyz, 6, 16
# ...
